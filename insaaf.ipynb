# %%
import pandas as pd
df=pd.read_csv('census_2011.csv')
df1=df.copy()

# %%
df.columns
# Out:
# Index(['District code', 'State name', 'District name', 'Population', 'Male',
#        'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC',
#        ...
#        'Power_Parity_Rs_90000_150000', 'Power_Parity_Rs_45000_150000',
#        'Power_Parity_Rs_150000_240000', 'Power_Parity_Rs_240000_330000',
#        'Power_Parity_Rs_150000_330000', 'Power_Parity_Rs_330000_425000',
#        'Power_Parity_Rs_425000_545000', 'Power_Parity_Rs_330000_545000',
#        'Power_Parity_Above_Rs_545000', 'Total_Power_Parity'],
#       dtype='object', length=118)

# %%
df1=df[[
    'State name',
    'District name',
    'Population',
    'Male',
    'Female',
    'Literate',
    'Male_Literate',
    'Female_Literate',
    'Rural_Households',
    'Urban_Households',
    'Households',
    'Age_Group_0_29',
    'Age_Group_30_49',
    'Age_Group_50',
    'Age not stated']]

# %%
df1.rename(columns={
    'State name': 'State/UT',
    'District name': 'District',
    'Male_Literate': 'Literate_Male',
    'Female_Literate': 'Literate_Female',
    'Rural_Households': 'Households_Rural',
    'Urban_Households': 'Households_Urban',
    'Age_Group_0_29': 'Young_and_Adult',
    'Age_Group_30_49': 'Middle_Aged',
    'Age_Group_50': 'Senior_Citizen',
    'Age not stated': 'Age_Not_Stated'
}, inplace=True)
# Out:
# /var/folders/hn/4bqqyrnx02sg3vxwj2nlv9lw0000gp/T/ipykernel_29835/3579045105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={

# %%
df1
# Out:
#                         State/UT                   District  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# 0    474190.0  396164.0  439654.0       282823.0         156831.0
# 1         NaN  355704.0  335649.0       207741.0         127908.0
# 2     78971.0   54516.0   93770.0        62834.0          30936.0
# 3         NaN   63017.0       NaN        56301.0          29935.0
# 4    251899.0  224936.0  261724.0       163333.0          98391.0
# ..        ...       ...       ...            ...              ...
# 635   19143.0   22673.0   36470.0        16610.0          19860.0
# 636   97809.0  102413.0  154916.0        79903.0          75013.0
# 637   20727.0       NaN   25332.0        15397.0           9935.0
# 638   54861.0   50736.0   78683.0        43186.0          35497.0
# 639  127283.0  110859.0  190266.0       105794.0          84472.0
#
#      Households_Rural  Households_Urban  Households  Young_and_Adult  \
# 0            158438.0               NaN    181664.0         600759.0
# 1            160649.0           27190.0    187839.0         503223.0
# 2             36920.0           17474.0     54394.0          70703.0
# 3             40370.0            7774.0     48144.0          87532.0
# 4            132139.0           15269.0    147408.0         304979.0
# ..                ...               ...         ...              ...
# 635               0.0           12110.0     12110.0          19760.0
# 636           35618.0           33715.0     69333.0              NaN
# 637           15958.0               0.0     15958.0          18786.0
# 638           39091.0            1094.0     40185.0          57350.0
# 639           34901.0           50631.0     85532.0         128402.0
#
#      Middle_Aged  Senior_Citizen  Age_Not_Stated
# 0       178435.0         89679.0          1481.0
# 1       160933.0         88978.0           611.0
# 2        41515.0             NaN           250.0
# 3        35561.0         17488.0           221.0
# 4       109818.0         61334.0           704.0
# ..           ...             ...             ...
# 635          NaN          9428.0            85.0
# 636      60089.0             NaN           366.0
# 637      12088.0          5922.0            46.0
# 638      30741.0         17464.0            42.0
# 639      76332.0         33128.0           280.0
#
# [640 rows x 15 columns]

# %%
def format_state_name(state):
    words = state.split()
    formatted_words = [word.lower() if word.lower() == 'and' else word.title() for word in words]
    return ' '.join(formatted_words)

# Apply the formatting function to the 'State/UT' column
df1['State/UT'] = df1['State/UT'].apply(format_state_name)
# Out:
# /var/folders/hn/4bqqyrnx02sg3vxwj2nlv9lw0000gp/T/ipykernel_29835/500510513.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['State/UT'] = df1['State/UT'].apply(format_state_name)

# %%
df1['State/UT']
# Out:
# 0                Jammu and Kashmir
# 1                Jammu and Kashmir
# 2                Jammu and Kashmir
# 3                Jammu and Kashmir
# 4                Jammu and Kashmir
#                   ...
# 635                    Pondicherry
# 636                    Pondicherry
# 637    Andaman and Nicobar Islands
# 638    Andaman and Nicobar Islands
# 639    Andaman and Nicobar Islands
# Name: State/UT, Length: 640, dtype: object

# %%
df1.to_csv('census.csv',index=False)

# %%
new_df=pd.read_csv('census.csv')
new_df
# Out:
#                         State/UT                   District  Population  \
# 0              Jammu and Kashmir                    Kupwara    870354.0
# 1              Jammu and Kashmir                     Badgam    753745.0
# 2              Jammu and Kashmir                Leh(Ladakh)    133487.0
# 3              Jammu and Kashmir                     Kargil    140802.0
# 4              Jammu and Kashmir                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  Pondicherry                       Mahe     41816.0
# 636                  Pondicherry                   Karaikal    200222.0
# 637  Andaman and Nicobar Islands                   Nicobars     36842.0
# 638  Andaman and Nicobar Islands  North  AND Middle Andaman    105597.0
# 639  Andaman and Nicobar Islands              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# 0    474190.0  396164.0  439654.0       282823.0         156831.0
# 1         NaN  355704.0  335649.0       207741.0         127908.0
# 2     78971.0   54516.0   93770.0        62834.0          30936.0
# 3         NaN   63017.0       NaN        56301.0          29935.0
# 4    251899.0  224936.0  261724.0       163333.0          98391.0
# ..        ...       ...       ...            ...              ...
# 635   19143.0   22673.0   36470.0        16610.0          19860.0
# 636   97809.0  102413.0  154916.0        79903.0          75013.0
# 637   20727.0       NaN   25332.0        15397.0           9935.0
# 638   54861.0   50736.0   78683.0        43186.0          35497.0
# 639  127283.0  110859.0  190266.0       105794.0          84472.0
#
#      Households_Rural  Households_Urban  Households  Young_and_Adult  \
# 0            158438.0               NaN    181664.0         600759.0
# 1            160649.0           27190.0    187839.0         503223.0
# 2             36920.0           17474.0     54394.0          70703.0
# 3             40370.0            7774.0     48144.0          87532.0
# 4            132139.0           15269.0    147408.0         304979.0
# ..                ...               ...         ...              ...
# 635               0.0           12110.0     12110.0          19760.0
# 636           35618.0           33715.0     69333.0              NaN
# 637           15958.0               0.0     15958.0          18786.0
# 638           39091.0            1094.0     40185.0          57350.0
# 639           34901.0           50631.0     85532.0         128402.0
#
#      Middle_Aged  Senior_Citizen  Age_Not_Stated
# 0       178435.0         89679.0          1481.0
# 1       160933.0         88978.0           611.0
# 2        41515.0             NaN           250.0
# 3        35561.0         17488.0           221.0
# 4       109818.0         61334.0           704.0
# ..           ...             ...             ...
# 635          NaN          9428.0            85.0
# 636      60089.0             NaN           366.0
# 637      12088.0          5922.0            46.0
# 638      30741.0         17464.0            42.0
# 639      76332.0         33128.0           280.0
#
# [640 rows x 15 columns]

# %%
# Read the list of Telangana districts from the text file
telangana_districts_file = 'Telangana.txt'
with open(telangana_districts_file, 'r') as file:
    telangana_districts = [line.strip() for line in file]

# Rename the State/UT from "Andhra Pradesh" to "Telangana" for the specified districts
new_df.loc[new_df['District'].isin(telangana_districts), 'State/UT'] = 'Telangana'

# %%
ladakh_districts_file = 'Laddakh.txt'
with open(ladakh_districts_file, 'r') as file:
    ladakh_districts = [line.strip() for line in file]

# Rename the State/UT from "Andhra Pradesh" to "Telangana" for the specified districts
new_df.loc[new_df['District'].isin(ladakh_districts), 'State/UT'] = 'Laddakh'

# %%
new_df.to_csv('census.csv',index=False)

# %%
new_df2=pd.read_csv('census.csv')

# %%
new_df2
# Out:
#                         State/UT                   District  Population  \
# 0              Jammu and Kashmir                    Kupwara    870354.0
# 1              Jammu and Kashmir                     Badgam    753745.0
# 2              Jammu and Kashmir                Leh(Ladakh)    133487.0
# 3                        Laddakh                     Kargil    140802.0
# 4              Jammu and Kashmir                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  Pondicherry                       Mahe     41816.0
# 636                  Pondicherry                   Karaikal    200222.0
# 637  Andaman and Nicobar Islands                   Nicobars     36842.0
# 638  Andaman and Nicobar Islands  North  AND Middle Andaman    105597.0
# 639  Andaman and Nicobar Islands              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# 0    474190.0  396164.0  439654.0       282823.0         156831.0
# 1         NaN  355704.0  335649.0       207741.0         127908.0
# 2     78971.0   54516.0   93770.0        62834.0          30936.0
# 3         NaN   63017.0       NaN        56301.0          29935.0
# 4    251899.0  224936.0  261724.0       163333.0          98391.0
# ..        ...       ...       ...            ...              ...
# 635   19143.0   22673.0   36470.0        16610.0          19860.0
# 636   97809.0  102413.0  154916.0        79903.0          75013.0
# 637   20727.0       NaN   25332.0        15397.0           9935.0
# 638   54861.0   50736.0   78683.0        43186.0          35497.0
# 639  127283.0  110859.0  190266.0       105794.0          84472.0
#
#      Households_Rural  Households_Urban  Households  Young_and_Adult  \
# 0            158438.0               NaN    181664.0         600759.0
# 1            160649.0           27190.0    187839.0         503223.0
# 2             36920.0           17474.0     54394.0          70703.0
# 3             40370.0            7774.0     48144.0          87532.0
# 4            132139.0           15269.0    147408.0         304979.0
# ..                ...               ...         ...              ...
# 635               0.0           12110.0     12110.0          19760.0
# 636           35618.0           33715.0     69333.0              NaN
# 637           15958.0               0.0     15958.0          18786.0
# 638           39091.0            1094.0     40185.0          57350.0
# 639           34901.0           50631.0     85532.0         128402.0
#
#      Middle_Aged  Senior_Citizen  Age_Not_Stated
# 0       178435.0         89679.0          1481.0
# 1       160933.0         88978.0           611.0
# 2        41515.0             NaN           250.0
# 3        35561.0         17488.0           221.0
# 4       109818.0         61334.0           704.0
# ..           ...             ...             ...
# 635          NaN          9428.0            85.0
# 636      60089.0             NaN           366.0
# 637      12088.0          5922.0            46.0
# 638      30741.0         17464.0            42.0
# 639      76332.0         33128.0           280.0
#
# [640 rows x 15 columns]

# %%
new_df2.isnull().sum()
# Out:
# State/UT             0
# District             0
# Population          30
# Male                30
# Female              33
# Literate            36
# Literate_Male       31
# Literate_Female     27
# Households_Rural    42
# Households_Urban    33
# Households          32
# Young_and_Adult     31
# Middle_Aged         30
# Senior_Citizen      31
# Age_Not_Stated      35
# dtype: int64

# %% [markdown]
# Missing percentage calculation before filling the values.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df3 = pd.read_csv('census.csv')

# Calculate the percentage of missing data for each column before filling
missing_percentage_before = (df3.isnull().sum() / len(df3)) * 100

# Fill missing data based on provided hints
df3['Population'].fillna(df3['Male'] + df1['Female'], inplace=True)
df3['Literate'].fillna(df3['Literate_Male'] + df3['Literate_Female'], inplace=True)
df3['Young_and_Adult'].fillna(df3['Population'] - df3['Middle_Aged'] - df3['Senior_Citizen'] - df3['Age_Not_Stated'], inplace=True)
df3['Households'].fillna(df3['Households_Rural'] + df3['Households_Urban'], inplace=True)

# Calculate the percentage of missing data for each column after filling
missing_percentage_after = (df3.isnull().sum() / len(df3)) * 100

# %%
df3.to_csv('new_census.csv',index=False)

# Visualize the impact of the data-filling process
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x=['Before Filling', 'After Filling'], y=[missing_percentage_before.mean(), missing_percentage_after.mean()])
plt.title('Comparison of Missing Data Before and After Filling')
plt.ylabel('Average Percentage of Missing Data')
plt.show()

# %%
final_df=pd.read_csv('new_census.csv')
final_df.isnull().sum()
# Out:
# State/UT             0
# District             0
# Population           1
# Male                30
# Female              33
# Literate             2
# Literate_Male       31
# Literate_Female     27
# Households_Rural    42
# Households_Urban    33
# Households           5
# Young_and_Adult      4
# Middle_Aged         30
# Senior_Citizen      31
# Age_Not_Stated      35
# dtype: int64

# %%
final_df[final_df['Literate'].isnull()]
# Out:
#         State/UT        District  Population       Male     Female  Literate  \
# 329  West Bengal  Uttar Dinajpur   3007134.0  1551066.0  1456068.0       NaN
# 568    Karnataka           Udupi   1177361.0   562131.0   615230.0       NaN
#
#      Literate_Male  Literate_Female  Households_Rural  Households_Urban  \
# 329       853495.0              NaN          683981.0           94269.0
# 568            NaN         460725.0          269817.0          115572.0
#
#      Households  Young_and_Adult  Middle_Aged  Senior_Citizen  Age_Not_Stated
# 329    778250.0        1916033.0     704859.0        385155.0          1087.0
# 568    385389.0         559565.0     340903.0        276234.0           659.0

# %%
final_df['District'].value_counts()
# Out:
# Raigarh          2
# Hamirpur         2
# Aurangabad       2
# Bijapur          2
# Bilaspur         2
#                 ..
# Muzaffarpur      1
# Gopalganj        1
# Siwan            1
# Saran            1
# South Andaman    1
# Name: District, Length: 634, dtype: int64

# %%
housing=pd.read_csv('housing.csv')
housing
# Out:
#       State Code                 State Name  District Code  \
# 0              1            JAMMU & KASHMIR              1
# 1              1            JAMMU & KASHMIR              1
# 2              1            JAMMU & KASHMIR              1
# 3              1            JAMMU & KASHMIR              2
# 4              1            JAMMU & KASHMIR              2
# ...          ...                        ...            ...
# 1903          35  ANDAMAN & NICOBAR ISLANDS            639
# 1904          35  ANDAMAN & NICOBAR ISLANDS            639
# 1905          35  ANDAMAN & NICOBAR ISLANDS            640
# 1906          35  ANDAMAN & NICOBAR ISLANDS            640
# 1907          35  ANDAMAN & NICOBAR ISLANDS            640
#
#                 District Name  Tehsil Code              Tehsil Name  \
# 0                     Kupwara            0                  Kupwara
# 1                     Kupwara            0                  Kupwara
# 2                     Kupwara            0                  Kupwara
# 3                      Badgam            0                   Badgam
# 4                      Badgam            0                   Badgam
# ...                       ...          ...                      ...
# 1903  North  & Middle Andaman            0  North  & Middle Andaman
# 1904  North  & Middle Andaman            0  North  & Middle Andaman
# 1905            South Andaman            0            South Andaman
# 1906            South Andaman            0            South Andaman
# 1907            South Andaman            0            South Andaman
#
#       Town Code/Village code  Ward No                           Area Name  \
# 0                          0        0                  District - Kupwara
# 1                          0        0                  District - Kupwara
# 2                          0        0                  District - Kupwara
# 3                          0        0                   District - Badgam
# 4                          0        0                   District - Badgam
# ...                      ...      ...                                 ...
# 1903                       0        0  District - North  & Middle Andaman
# 1904                       0        0  District - North  & Middle Andaman
# 1905                       0        0            District - South Andaman
# 1906                       0        0            District - South Andaman
# 1907                       0        0            District - South Andaman
#
#      Rural/Urban  ...  Contition_T_Total  Contition_T_Good  \
# 0          Rural  ...                100              33.6
# 1          Total  ...                100              34.8
# 2          Urban  ...                100              45.7
# 3          Rural  ...                100              49.7
# 4          Total  ...                100              51.6
# ...          ...  ...                ...               ...
# 1903       Total  ...                100              52.6
# 1904       Urban  ...                100              37.5
# 1905       Rural  ...                100              63.0
# 1906       Total  ...                100              71.5
# 1907       Urban  ...                100              77.4
#
#       Contition_T_Livable  Contition_T_Dilapidated  Contition_R_Total  \
# 0                    58.1                      8.3               90.9
# 1                    57.3                      7.9               91.0
# 2                    49.5                      4.8               91.8
# 3                    46.3                      3.9               97.2
# 4                    44.7                      3.8               97.3
# ...                   ...                      ...                ...
# 1903                 44.6                      2.8               97.5
# 1904                 55.9                      6.6               95.8
# 1905                 33.5                      3.5               98.3
# 1906                 26.4                      2.2               98.5
# 1907                 21.4                      1.2               98.7
#
#       Residence_Good  Residence_Livable  Residence_Dilapidated  \
# 0               32.7               51.0                    7.2
# 1               33.8               50.2                    6.9
# 2               45.0               42.2                    4.5
# 3               49.0               44.5                    3.7
# 4               50.8               43.0                    3.5
# ...              ...                ...                    ...
# 1903            51.2               43.5                    2.8
# 1904            36.3               53.0                    6.5
# 1905            62.0               32.8                    3.5
# 1906            70.6               25.8                    2.1
# 1907            76.6               20.9                    1.2
#
#       Residence_cum_other  Residence_cum_Good
# 0                     9.1                 1.0
# 1                     9.0                 0.9
# 2                     8.2                 0.7
# 3                     2.8                 0.7
# 4                     2.7                 0.8
# ...                   ...                 ...
# 1903                  2.5                 1.4
# 1904                  4.2                 1.2
# 1905                  1.7                 1.0
# 1906                  1.5                 0.9
# 1907                  1.3                 0.8
#
# [1908 rows x 156 columns]

# %%
housing['Rural/Urban'].value_counts()
# Out:
# Total    640
# Urban    637
# Rural    631
# Name: Rural/Urban, dtype: int64

# %%
final_census=pd.read_csv('new_census.csv')
final_housing=pd.read_csv('housing.csv')
merged_data = pd.merge(final_census, final_housing, on='Districts')

# Calculate the absolute values for Total Number of Dilapidated and Latrine_premise
merged_data['Absolute_Dilapidated'] = abs(merged_data['Total Number of Dilapidated'])
merged_data['Absolute_Latrine_premise'] = abs(merged_data['Latrine_premise'])

# Group by district and sum for both rural and urban areas
result = merged_data.groupby('districts').agg({
    'Absolute_Dilapidated': 'sum',
    'Absolute_Latrine_premise': 'sum'
}).reset_index()

# Display the result
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/ZIII/Downloads/DS - Python + SQL + ETL - Healthcare Census (4)/DS - Python + SQL + ETL - Healthcare Census/Data/insaaf.ipynb Cell 27 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/ZIII/Downloads/DS%20-%20Python%20%2B%20SQL%20%2B%20ETL%20-%20Healthcare%20Census%20%284%29/DS%20-%20Python%20%2B%20SQL%20%2B%20ETL%20-%20Healthcare%20Census/Data/insaaf.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> final_census=pd.read_csv('new_census.csv')
#       <a href='vscode-notebook-cell:/Users/ZIII/Downloads/DS%20-%20Python%20%2B%20SQL%20%2B%20ETL%20-%20Healthcare%20Census%20%284%29/DS%20-%20Python%20%2B%20SQL%20%2B%20ETL%20-%20Healthcare%20Census/Data/insaaf.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> final_housing=pd.read_csv('housing.csv')
# ----> <a href='vscode-notebook-cell:/Users/ZIII/Downloads/DS%20-%20Python%20%2B%20SQL%20%2B%20ETL%20-%20Healthcare%20Census%20%284%29/DS%20-%20Python%20%2B%20SQL%20%2B%20ETL%20-%20Healthcare%20Census/Data/insaaf.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> merged_data = pd.merge(final_census, final_housing, on='Districts')
#       <a href='vscode-notebook-cell:/Users/ZIII/Downloads/DS%20-%20Python%20%2B%20SQL%20%2B%20ETL%20-%20Healthcare%20Census%20%284%29/DS%20-%20Python%20%2B%20SQL%20%2B%20ETL%20-%20Healthcare%20Census/Data/insaaf.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a> # Calculate the absolute values for Total Number of Dilapidated and Latrine_premise
#       <a href='vscode-notebook-cell:/Users/ZIII/Downloads/DS%20-%20Python%20%2B%20SQL%20%2B%20ETL%20-%20Healthcare%20Census%20%284%29/DS%20-%20Python%20%2B%20SQL%20%2B%20ETL%20-%20Healthcare%20Census/Data/insaaf.ipynb#X36sZmlsZQ%3D%3D?line=5'>6</a> merged_data['Absolute_Dilapidated'] = abs(merged_data['Total Number of Dilapidated'])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/reshape/merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/reshape/merge.py:700, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     693 self._cross = cross_col
#     695 # note this function has side effects
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
# --> 700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
#     704 self._maybe_coerce_merge_keys()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/reshape/merge.py:1097, in _MergeOperation._get_merge_keys(self)
#    1095 if not is_rkey(rk):
#    1096     if rk is not None:
# -> 1097         right_keys.append(right._get_label_or_level_values(rk))
#    1098     else:
#    1099         # work-around for merge_asof(right_index=True)
#    1100         right_keys.append(right.index)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'Districts'
